# %%
import utils
from slate import PDF
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Leitura de PDFs

# %%
#Ano de 2012 - INCC
arquivos = glob.glob('F:\Iniciação Científica\Dados\IBRE\INCC\\ano 2012\*.pdf')
if arquivos == []:
    arquivos = glob.glob('G:\Iniciação Científica\Dados\IBRE\INCC\\ano 2012\*')
incc_0112 = []
incc_0212 = []
incc_0312 = []
incc_0412 = []
incc_0512 = []
incc_0612 = []
incc_0712 = []
incc_0812 = []
incc_0912 = []
incc_1012 = []
incc_1112 = []
incc_1212 = []
count = 0
for arq in arquivos:
    count += 1
    with open(arq, 'rb') as f:
        doc = PDF(f)
    if count == 1:
        for i in range(3):
            incc_0112.append(''.join(doc[i].split('\n')))
    if count == 2:
        for i in range(3):
            incc_0212.append(''.join(doc[i].split('\n')))
    if count == 3:
        for i in range(3):
            incc_0312.append(''.join(doc[i].split('\n')))
    if count == 4:
        for i in range(3):
            incc_0412.append(''.join(doc[i].split('\n')))
    if count == 5:
        for i in range(3):
            incc_0512.append(''.join(doc[i].split('\n')))
    if count == 6:
        for i in range(3):
            incc_0612.append(''.join(doc[i].split('\n')))
    if count == 7:
        for i in range(3):
            incc_0712.append(''.join(doc[i].split('\n')))
    if count == 8:
        for i in range(3):
            incc_0812.append(''.join(doc[i].split('\n')))
    if count == 9:
        for i in range(3):
            incc_0912.append(''.join(doc[i].split('\n')))
    if count == 10:
        for i in range(3):
            incc_1012.append(''.join(doc[i].split('\n')))
    if count == 11:
        for i in range(3):
            incc_1112.append(''.join(doc[i].split('\n')))
    if count == 12:
        for i in range(3):
            incc_1212.append(''.join(doc[i].split('\n')))
# Out:
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (145) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (144) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (144) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (150) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (150) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.

# %%
#Ano 2013 - INCC
arquivos = glob.glob('F:\Iniciação Científica\Dados\IBRE\INCC\\ano 2013\*.pdf')
if arquivos == []:
    arquivos = glob.glob('G:\Iniciação Científica\Dados\IBRE\INCC\\ano 2013\*.pdf')
incc_0113 = []
incc_0213 = []
incc_0313 = []
incc_0413 = []
incc_0513 = []
incc_0613 = []
incc_0713 = []
incc_0813 = []
incc_0913 = []
incc_1013 = []
incc_1113 = []
incc_1213 = []
count = 0
for arq in arquivos:
    count += 1
    with open(arq, 'rb') as f:
        doc = PDF(f)
    if count == 1:
        for i in range(3):
            incc_0113.append(''.join(doc[i].split('\n')))
    if count == 2:
        for i in range(3):
            incc_0213.append(''.join(doc[i].split('\n')))
    if count == 3:
        for i in range(3):
            incc_0313.append(''.join(doc[i].split('\n')))
    if count == 4:
        for i in range(3):
            incc_0413.append(''.join(doc[i].split('\n')))
    if count == 5:
        for i in range(3):
            incc_0513.append(''.join(doc[i].split('\n')))
    if count == 6:
        for i in range(3):
            incc_0613.append(''.join(doc[i].split('\n')))
    if count == 7:
        for i in range(3):
            incc_0713.append(''.join(doc[i].split('\n')))
    if count == 8:
        for i in range(3):
            incc_0813.append(''.join(doc[i].split('\n')))
    if count == 9:
        for i in range(3):
            incc_0913.append(''.join(doc[i].split('\n')))
    if count == 10:
        for i in range(3):
            incc_1013.append(''.join(doc[i].split('\n')))
    if count == 11:
        for i in range(3):
            incc_1113.append(''.join(doc[i].split('\n')))
    if count == 12:
        for i in range(3):
            incc_1213.append(''.join(doc[i].split('\n')))
# Out:
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (149) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.

# %%
#Ano 2014 - INCC
arquivos = glob.glob('F:\Iniciação Científica\Dados\IBRE\INCC\\ano 2014\*.pdf')
if arquivos == []:
    arquivos = glob.glob('G:\Iniciação Científica\Dados\IBRE\INCC\\ano 2014\*.pdf')
incc_0114 = []
incc_0214 = []
incc_0314 = []
incc_0414 = []
incc_0514 = []
incc_0614 = []
incc_0714 = []
incc_0814 = []
incc_0914 = []
incc_1014 = []
incc_1114 = []
incc_1214 = []
count = 0
for arq in arquivos:
    count += 1
    with open(arq, 'rb') as f:
        doc = PDF(f)
    if count == 1:
        for i in range(3):
            incc_0114.append(''.join(doc[i].split('\n')))
    if count == 2:
        for i in range(3):
            incc_0214.append(''.join(doc[i].split('\n')))
    if count == 3:
        for i in range(3):
            incc_0314.append(''.join(doc[i].split('\n')))
    if count == 4:
        for i in range(3):
            incc_0414.append(''.join(doc[i].split('\n')))
    if count == 5:
        for i in range(3):
            incc_0514.append(''.join(doc[i].split('\n')))
    if count == 6:
        for i in range(3):
            incc_0614.append(''.join(doc[i].split('\n')))
    if count == 7:
        for i in range(3):
            incc_0714.append(''.join(doc[i].split('\n')))
    if count == 8:
        for i in range(3):
            incc_0814.append(''.join(doc[i].split('\n')))
    if count == 9:
        for i in range(3):
            incc_0914.append(''.join(doc[i].split('\n')))
    if count == 10:
        for i in range(3):
            incc_1014.append(''.join(doc[i].split('\n')))
    if count == 11:
        for i in range(3):
            incc_1114.append(''.join(doc[i].split('\n')))
    if count == 12:
        for i in range(3):
            incc_1214.append(''.join(doc[i].split('\n')))
# Out:
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (149) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (150) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (150) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.

# %%
#Ano 2015 - INCC
arquivos = glob.glob('F:\Iniciação Científica\Dados\IBRE\INCC\\ano 2015\*.pdf')
if arquivos == []:
    arquivos = glob.glob('G:\Iniciação Científica\Dados\IBRE\INCC\\ano 2015\*.pdf')
incc_0115 = []
incc_0215 = []
incc_0315 = []
incc_0415 = []
incc_0515 = []
incc_0615 = []
incc_0715 = []
incc_0815 = []
incc_0915 = []
incc_1015 = []
incc_1115 = []
incc_1215 = []
count = 0
for arq in arquivos:
    count += 1
    with open(arq, 'rb') as f:
        doc = PDF(f)
    if count == 1:
        for i in range(3):
            incc_0115.append(''.join(doc[i].split('\n')))
    if count == 2:
        for i in range(3):
            incc_0215.append(''.join(doc[i].split('\n')))
    if count == 3:
        for i in range(3):
            incc_0315.append(''.join(doc[i].split('\n')))
    if count == 4:
        for i in range(3):
            incc_0415.append(''.join(doc[i].split('\n')))
    if count == 5:
        for i in range(3):
            incc_0515.append(''.join(doc[i].split('\n')))
    if count == 6:
        for i in range(3):
            incc_0615.append(''.join(doc[i].split('\n')))
    if count == 7:
        for i in range(3):
            incc_0715.append(''.join(doc[i].split('\n')))
    if count == 8:
        for i in range(3):
            incc_0815.append(''.join(doc[i].split('\n')))
    if count == 9:
        for i in range(3):
            incc_0915.append(''.join(doc[i].split('\n')))
    if count == 10:
        for i in range(3):
            incc_1015.append(''.join(doc[i].split('\n')))
    if count == 11:
        for i in range(3):
            incc_1115.append(''.join(doc[i].split('\n')))
    if count == 12:
        for i in range(3):
            incc_1215.append(''.join(doc[i].split('\n')))
# Out:
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.

# %%
#Ano 2016 - INCC
arquivos = glob.glob('F:\Iniciação Científica\Dados\IBRE\INCC\\ano 2016\*.pdf')
if arquivos == []:
    arquivos = glob.glob('G:\Iniciação Científica\Dados\IBRE\INCC\\ano 2016\*.pdf')
incc_0116 = []
incc_0216 = []
incc_0316 = []
incc_0416 = []
incc_0516 = []
incc_0616 = []
incc_0716 = []
incc_0816 = []
incc_1016 = []
incc_1116 = []
incc_1216 = []
count = 0
for arq in arquivos:
    count += 1
    with open(arq, 'rb') as f:
        doc = PDF(f)
    if count == 1:
        for i in range(3):
            incc_0116.append(''.join(doc[i].split('\n')))
    if count == 2:
        for i in range(3):
            incc_0216.append(''.join(doc[i].split('\n')))
    if count == 3:
        for i in range(3):
            incc_0316.append(''.join(doc[i].split('\n')))
    if count == 4:
        for i in range(3):
            incc_0416.append(''.join(doc[i].split('\n')))
    if count == 5:
        for i in range(3):
            incc_0516.append(''.join(doc[i].split('\n')))
    if count == 6:
        for i in range(3):
            incc_0616.append(''.join(doc[i].split('\n')))
    if count == 7:
        for i in range(3):
            incc_0716.append(''.join(doc[i].split('\n')))
    if count == 8:
        for i in range(3):
            incc_0816.append(''.join(doc[i].split('\n')))
    if count == 9:
        for i in range(3):
            incc_1016.append(''.join(doc[i].split('\n')))
    if count == 10:
        for i in range(3):
            incc_1116.append(''.join(doc[i].split('\n')))
    if count == 11:
        for i in range(3):
            incc_1216.append(''.join(doc[i].split('\n')))
# Out:
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (152) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (153) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (154) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (155) to group, skipping.

# %% [markdown]
# # INCC

# %%
var_incc_st12 = []
incc = [incc_0112,
incc_0212,
incc_0312,
incc_0412,
incc_0512,
incc_0612,
incc_0712,
incc_0812,
incc_0912,
incc_1012,
incc_1112,
incc_1212]
for lista in incc:
    try:
        ind = lista[0].split(' ').index('acima')
        var_incc_st12.append(lista[0].split(' ')[ind-1])
    except:
        ind = lista[0].split(' ').index('abaixo')
        var_incc_st12.append(lista[0].split(' ')[ind-1])

# %%
var_incc_st13 = []
incc = [incc_0113,
incc_0213,
incc_0313,
incc_0413,
incc_0513,
incc_0613,
incc_0713,
incc_0813,
incc_0913,
incc_1013,
incc_1113,
incc_1213]
for lista in incc:
    try:
        ind = lista[0].split(' ').index('acima')
        var_incc_st13.append(lista[0].split(' ')[ind-1])
    except:
        ind = lista[0].split(' ').index('abaixo')
        var_incc_st13.append(lista[0].split(' ')[ind-1])

# %%
incc = [incc_0114,
incc_0214,
incc_0314,
incc_0414,
incc_0514,
incc_0614,
incc_0714,
incc_0814,
incc_0914,
incc_1014,
incc_1114,
incc_1214]
var_incc_st14 = []
for lista in incc:
    try:
        ind = lista[0].split(' ').index('acima')
        var_incc_st14.append(lista[0].split(' ')[ind-1])
    except:
        ind = lista[0].split(' ').index('abaixo')
        var_incc_st14.append(lista[0].split(' ')[ind-1])

# %%
incc = [incc_0115,
incc_0215,
incc_0315,
incc_0415,
incc_0515,
incc_0615,
incc_0715,
incc_0815,
incc_0915,
incc_1015,
incc_1115,
incc_1215]
var_incc_st15 = []
for lista in incc:
    try:
        ind = lista[0].split(' ').index('acima')
        var_incc_st15.append(lista[0].split(' ')[ind-1])
    except:
        ind = lista[0].split(' ').index('abaixo')
        var_incc_st15.append(lista[0].split(' ')[ind-1])

# %%
incc = [incc_0116,
incc_0216,
incc_0316,
incc_0416,
incc_0516,
incc_0616,
incc_0716,
incc_0816,
incc_1016,
incc_1116,
incc_1216]
var_incc_st16 = []
count = 0
for lista in incc:
    count += 1
    if count != 9 :
        try:
            ind = lista[0].split(' ').index('acima')
            var_incc_st16.append(lista[0].split(' ')[ind-1])
        except:
            try:
                ind = lista[0].lower().split(' ').index('abaixo')
                var_incc_st16.append(lista[0].split(' ')[ind-1])
            except:
                ind = lista[0].lower().split(' ').index('mesma')
                var_incc_st16.append(lista[0].split(' ')[ind+6])
    elif count == 9:
        ind1 = lista[0].split(' ').index('abaixo')
        var_incc_st16.append(lista[0].split(' ')[ind+7])
        ind2 = lista[0].split(' ').index('abaixo')
        var_incc_st16.append(lista[0].split(' ')[ind-1])

# %%
var_incc_st12 = ','.join(var_incc_st12).split(',')
var_incc_st12 = ''.join(var_incc_st12).split('%')
var_incc_st12.remove(var_incc_st12[12])
var_incc_12 = []
for num in var_incc_st12:
    per = float(num)
    per = per/100
    var_incc_12.append(per)

# %%
var_incc_st13 = ','.join(var_incc_st13).split(',')
var_incc_st13 = ''.join(var_incc_st13).split('%')
var_incc_st13.remove(var_incc_st13[12])
var_incc_13 = []
for num in var_incc_st13:
    per = float(num)
    per = per/100
    var_incc_13.append(per)

# %%
var_incc_st14 = ','.join(var_incc_st14).split(',')
var_incc_st14 = ''.join(var_incc_st14).split('%')
var_incc_st14.remove(var_incc_st14[12])
var_incc_14 = []
for num in var_incc_st14:
    per = float(num)
    per = per/100
    var_incc_14.append(per)

# %%
var_incc_st15 = ','.join(var_incc_st15).split(',')
var_incc_st15 = ''.join(var_incc_st15).split('%')
var_incc_st15.remove(var_incc_st15[12])
var_incc_15 = []
for num in var_incc_st15:
    per = float(num)
    per = per/100
    var_incc_15.append(per)

# %%
var_incc_st16 = ','.join(var_incc_st16).split(',')
var_incc_st16 = ''.join(var_incc_st16).split('%')
var_incc_st16.remove(var_incc_st16[12])
var_incc_16 = []
count = 0
for num in var_incc_st16:
    count += 1
    per = float(num)
    if count == 10:
        var_incc_16.append(per*10)
    elif count == 12:
        var_incc_16.append(per*10)
    else:
        per = per/100
        var_incc_16.append(per)

# %%
mes = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
dic = {'Ano': mes, '2012': var_incc_12, '2013':var_incc_13, '2014':var_incc_14, '2015':var_incc_15, '2016':var_incc_16}
df = pd.DataFrame(dic)

# %% [markdown]
# # Materias, Equipamentos e Serviços

# %%
var_incc_mes12 = []
incc = [incc_0112,
incc_0212,
incc_0312,
incc_0412,
incc_0512,
incc_0612,
incc_0712,
incc_0812,
incc_0912,
incc_1012,
incc_1112,
incc_1212]
for lista in incc:
    if (lista == incc_0612) or (lista == incc_0712) or (lista == incc_1012) or (lista == incc_1112) or (lista == incc_1212):
        ind = lista[0].split(' ').index('Servi')
        var_incc_mes12.append(lista[0].split(' ')[ind+6])
    else:
        ind = lista[0].split(' ').index('Serviços')
        var_incc_mes12.append(lista[0].split(' ')[ind+4])

# %%
var_incc_mes13 = []
incc = [incc_0113,
incc_0213,
incc_0313,
incc_0413,
incc_0513,
incc_0613,
incc_0713,
incc_0813,
incc_0913,
incc_1013,
incc_1113,
incc_1213]
for lista in incc:
    ind = lista[0].split(' ').index('Serviços')
    var_incc_mes13.append(lista[0].split(' ')[ind+4])

# %%
incc = [incc_0114,
incc_0214,
incc_0314,
incc_0414,
incc_0514,
incc_0614,
incc_0714,
incc_0814,
incc_0914,
incc_1014,
incc_1114,
incc_1214]
var_incc_mes14 = []
for lista in incc:
    ind = lista[0].split(' ').index('Serviços')
    var_incc_mes14.append(lista[0].split(' ')[ind+4])

# %%
incc = [incc_0115,
incc_0215,
incc_0315,
incc_0415,
incc_0515,
incc_0615,
incc_0715,
incc_0815,
incc_0915,
incc_1015,
incc_1115,
incc_1215]
var_incc_mes15 = []
for lista in incc:
    ind = lista[0].split(' ').index('Serviços')
    var_incc_mes15.append(lista[0].split(' ')[ind+4])

# %%
incc = [incc_0116,
incc_0216,
incc_0316,
incc_0416,
incc_0516,
incc_0616,
incc_0716,
incc_0816,
incc_1016,
incc_1116,
incc_1216]
var_incc_mes16 = []
count = 0
for lista in incc:
    count += 1
    if count != 9 :
        ind = lista[0].split(' ').index('Serviços')
        var_incc_mes16.append(lista[0].split(' ')[ind+4])
    elif count == 9:
        ind1 = lista[0].split(' ').index('Serviços')
        var_incc_mes16.append(lista[0].split(' ')[ind+13])
        ind2 = lista[0].split(' ').index('Serviços')
        var_incc_mes16.append(lista[0].split(' ')[ind+4])

# %%
var_incc_mes12 = '.'.join(var_incc_mes12).split('.')
var_incc_mes12 = ''.join(var_incc_mes12).split('%')
var_incc_mes12 = ','.join(var_incc_mes12).split(',')
var_incc_mes12.remove(var_incc_mes12[24])
var_mes_12 = []
for num in var_incc_mes12:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mes_12.append(per)

# %%
var_incc_mes13 = '.'.join(var_incc_mes13).split('.')
var_incc_mes13 = ''.join(var_incc_mes13).split('%')
var_incc_mes13 = ','.join(var_incc_mes13).split(',')
var_incc_mes13.remove(var_incc_mes13[24])
var_mes_13 = []
for num in var_incc_mes13:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mes_13.append(per)

# %%
var_incc_mes14 = '.'.join(var_incc_mes14).split('.')
var_incc_mes14 = ''.join(var_incc_mes14).split('%')
var_incc_mes14 = ','.join(var_incc_mes14).split(',')
var_incc_mes14.remove(var_incc_mes14[24])
var_mes_14 = []
for num in var_incc_mes14:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mes_14.append(per)

# %%
var_incc_mes15 = '.'.join(var_incc_mes15).split('.')
var_incc_mes15 = ''.join(var_incc_mes15).split('%')
var_incc_mes15 = ','.join(var_incc_mes15).split(',')
var_incc_mes15.remove(var_incc_mes15[24])
var_mes_15 = []
for num in var_incc_mes15:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mes_15.append(per)

# %%
var_incc_mes16 = '.'.join(var_incc_mes16).split('.')
var_incc_mes16 = ''.join(var_incc_mes16).split('%')
var_incc_mes16 = ','.join(var_incc_mes16).split(',')
var_incc_mes16.remove(var_incc_mes16[24])
var_mes_16 = []
for num in var_incc_mes16:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mes_16.append(per)

# %%
var_mes_16.remove(-0.0)
var_mes_16[10] = -1*var_mes_16[10]
mes = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
dic = {'Ano': mes, '2012': var_mes_12, '2013':var_mes_13, '2014':var_mes_14, '2015':var_mes_15, '2016':var_mes_16}
df1 = pd.DataFrame(dic)

# %% [markdown]
# # Mão de Obra

# %%
var_incc_mdo12 = []
incc = [incc_0112,
incc_0212,
incc_0312,
incc_0412,
incc_0512,
incc_0612,
incc_0712,
incc_0812,
incc_0912,
incc_1012,
incc_1112,
incc_1212]
for lista in incc:
    if lista == incc_0312:
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo12.append(lista[0].split(' ')[ind+9])
    elif (lista == incc_0612) or (lista == incc_0712) or (lista == incc_1012) or (lista == incc_1112) or (lista == incc_1212):
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo12.append(lista[0].split(' ')[ind+5])
    elif (lista == incc_0912):
        ind = incc_0812[0].split(' ').index('Obra')
        var_incc_mdo12.append(incc_0812[0].split(' ')[ind+4])
    else:
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo12.append(lista[0].split(' ')[ind+4])

# %%
var_incc_mdo13 = []
incc = [incc_0113,
incc_0213,
incc_0313,
incc_0413,
incc_0513,
incc_0613,
incc_0713,
incc_0813,
incc_0913,
incc_1013,
incc_1113,
incc_1213]
for lista in incc:
    if (lista == incc_1113) or (lista == incc_1213):
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo13.append(lista[0].split(' ')[ind+2])
    else:
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo13.append(lista[0].split(' ')[ind+4])
var_incc_mdo13[8] = var_incc_mdo13[7]
var_incc_mdo13[9] = var_incc_mdo13[7]

# %%
incc = [incc_0114,
incc_0214,
incc_0314,
incc_0414,
incc_0514,
incc_0614,
incc_0714,
incc_0814,
incc_0914,
incc_1014,
incc_1114,
incc_1214]
var_incc_mdo14 = []
for lista in incc:
    if (lista == incc_0114) or (lista == incc_0214):
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo14.append(lista[0].split(' ')[ind+2])
    else:
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo14.append(lista[0].split(' ')[ind+4])
var_incc_mdo14[8] = var_incc_mdo14[7]
var_incc_mdo14[9] = var_incc_mdo14[7]

# %%
incc = [incc_0115,
incc_0215,
incc_0315,
incc_0415,
incc_0515,
incc_0615,
incc_0715,
incc_0815,
incc_0915,
incc_1015,
incc_1115,
incc_1215]
var_incc_mdo15 = []
for lista in incc:
    ind = lista[0].split(' ').index('Obra')
    var_incc_mdo15.append(lista[0].split(' ')[ind+4])
var_incc_mdo15[8] = var_incc_mdo15[7]
var_incc_mdo15[9] = var_incc_mdo15[7]
var_incc_mdo15[10] = var_incc_mdo15[7]

# %%
incc = [incc_0116,
incc_0216,
incc_0316,
incc_0416,
incc_0516,
incc_0616,
incc_0716,
incc_0816,
incc_1016,
incc_1116,
incc_1216]
var_incc_mdo16 = []
count = 0
for lista in incc:
    count += 1
    if count != 9 :
        ind = lista[0].split(' ').index('Obra')
        var_incc_mdo16.append(lista[0].split(' ')[ind+4])
    elif count == 9:
        ind1 = lista[0].split(' ').index('Obra')
        var_incc_mdo16.append(lista[0].split(' ')[ind+14])
        ind2 = lista[0].split(' ').index('Obra')
        var_incc_mdo16.append(lista[0].split(' ')[ind+4])

# %%
var_incc_mdo12 = '.'.join(var_incc_mdo12).split('.')
var_incc_mdo12 = ''.join(var_incc_mdo12).split('%')
var_incc_mdo12 = ','.join(var_incc_mdo12).split(',')
var_incc_mdo12.remove(var_incc_mdo12[24])
var_mdo_12 = []
for num in var_incc_mdo12:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mdo_12.append(per)

# %%
var_incc_mdo13 = '.'.join(var_incc_mdo13).split('.')
var_incc_mdo13 = ''.join(var_incc_mdo13).split('%')
var_incc_mdo13 = ','.join(var_incc_mdo13).split(',')
var_incc_mdo13.remove(var_incc_mdo13[24])
var_mdo_13 = []
for num in var_incc_mdo13:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mdo_13.append(per)

# %%
var_incc_mdo14 = '.'.join(var_incc_mdo14).split('.')
var_incc_mdo14 = ''.join(var_incc_mdo14).split('%')
var_incc_mdo14 = ','.join(var_incc_mdo14).split(',')
var_incc_mdo14.remove(var_incc_mdo14[24])
var_mdo_14 = []
for num in var_incc_mdo14:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mdo_14.append(per)

# %%
var_incc_mdo15 = '.'.join(var_incc_mdo15).split('.')
var_incc_mdo15 = ''.join(var_incc_mdo15).split('%')
var_incc_mdo15 = ','.join(var_incc_mdo15).split(',')
var_incc_mdo15.remove(var_incc_mdo15[24])
var_mdo_15 = []
for num in var_incc_mdo15:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mdo_15.append(per)

# %%
var_incc_mdo16 = '.'.join(var_incc_mdo16).split('.')
var_incc_mdo16 = ''.join(var_incc_mdo16).split('%')
var_incc_mdo16 = ','.join(var_incc_mdo16).split(',')
var_incc_mdo16.remove(var_incc_mdo16[24])
var_mdo_16 = []
for num in var_incc_mdo16:
    if num == '0':
        pass
    else:
        per = float(num)
        per = per/100
        var_mdo_16.append(per)

# %%
var_mdo_12[4] = var_mdo_12[4] + var_mdo_12[3]*100
var_mdo_12[6] = var_mdo_12[6] + var_mdo_12[5]*100
var_mdo_12[8] = var_mdo_12[8] + var_mdo_12[7]*100
var_mdo_12[10] = var_mdo_12[10] + var_mdo_12[9]*100
var_mdo_12.remove(var_mdo_12[3])
var_mdo_12.remove(var_mdo_12[4])
var_mdo_12.remove(var_mdo_12[5])
var_mdo_12.remove(var_mdo_12[6])

# %%
var_mdo_13[2] = var_mdo_13[2] + var_mdo_13[1]*100
var_mdo_13[5] = var_mdo_13[5] + var_mdo_13[4]*100
var_mdo_13[7] = var_mdo_13[7] + var_mdo_13[6]*100
var_mdo_13[9] = var_mdo_13[9] + var_mdo_13[8]*100
var_mdo_13[11] = var_mdo_13[11] + var_mdo_13[10]*100
var_mdo_13.remove(var_mdo_13[1])
var_mdo_13.remove(var_mdo_13[3])
var_mdo_13.remove(var_mdo_13[4])
var_mdo_13.remove(var_mdo_13[5])
var_mdo_13.remove(var_mdo_13[6])

# %%
var_mdo_14[1] = var_mdo_14[1] + var_mdo_14[0]*100
var_mdo_14[6] = var_mdo_14[6] + var_mdo_14[5]*100
var_mdo_14[8] = var_mdo_14[8] + var_mdo_14[7]*100
var_mdo_14[10] = var_mdo_14[10] + var_mdo_14[9]*100
var_mdo_14.remove(var_mdo_14[0])
var_mdo_14.remove(var_mdo_14[4])
var_mdo_14.remove(var_mdo_14[5])
var_mdo_14.remove(var_mdo_14[6])

# %%
var_mdo_15[6] = var_mdo_15[6] + var_mdo_15[5]*100
var_mdo_15[8] = var_mdo_15[8] + var_mdo_15[7]*100
var_mdo_15[10] = var_mdo_15[10] + var_mdo_15[9]*100
var_mdo_15[12] = var_mdo_15[12] + var_mdo_15[11]*100
var_mdo_15[14] = var_mdo_15[14] + var_mdo_15[13]*100
var_mdo_15[16] = var_mdo_15[16] + var_mdo_15[15]*100
var_mdo_15.remove(var_mdo_15[5])
var_mdo_15.remove(var_mdo_15[6])
var_mdo_15.remove(var_mdo_15[7])
var_mdo_15.remove(var_mdo_15[8])
var_mdo_15.remove(var_mdo_15[9])
var_mdo_15.remove(var_mdo_15[10])

# %%
var_mdo_16[3] = var_mdo_16[3] + var_mdo_16[2]*100
var_mdo_16[7] = var_mdo_16[7] + var_mdo_16[6]*100
var_mdo_16[9] = var_mdo_16[9] + var_mdo_16[8]*100
var_mdo_16.remove(var_mdo_16[2])
var_mdo_16.remove(var_mdo_16[5])
var_mdo_16.remove(var_mdo_16[6])

# %%
mes = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']
dic = {'Ano': mes, '2012': var_mdo_12, '2013':var_mdo_13, '2014':var_mdo_14, '2015':var_mdo_15, '2016':var_mdo_16}
df2 = pd.DataFrame(dic)

# %%
df.to_csv('INCC.csv')
df1.to_csv('INCC_Mat_Eq_Serv.csv')
df2.to_csv('INCC_Mao_de_Obra.csv')
