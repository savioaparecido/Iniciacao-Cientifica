# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arquivos = glob.glob('G:\Iniciação Científica\Dados\IBGE\CNAE_2012\*.xls')
if arquivos == []:
    arquivos = glob.glob('F:\Iniciação Científica\Dados\IBGE\CNAE_2012\*.xls')
arquivos = sorted(arquivos)

# %%
print(arquivos)
# Out:
# ['G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb1.1.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb1.2.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb2.1.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb2.2.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb2.3.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb3.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb4.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb5.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb6.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb7.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb8.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tb9.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tbz10.xls', 'G:\\Iniciação Científica\\Dados\\IBGE\\CNAE_2012\\tbz11.xls']

# %%
len(arquivos)
# Out:
# 14

# %%
arq1_1 = pd.ExcelFile(arquivos[0])
arq1_2 = pd.ExcelFile(arquivos[1])
arq2_1 = pd.ExcelFile(arquivos[2])
arq2_2 = pd.ExcelFile(arquivos[3])
arq2_3 = pd.ExcelFile(arquivos[4])
arq3 = pd.ExcelFile(arquivos[5])
arq4 = pd.ExcelFile(arquivos[6])
arq5 = pd.ExcelFile(arquivos[7])
arq6 = pd.ExcelFile(arquivos[8])
arq7 = pd.ExcelFile(arquivos[9])
arq8 = pd.ExcelFile(arquivos[10])
arq9 = pd.ExcelFile(arquivos[11])
arq10 = pd.ExcelFile(arquivos[12])
arq11 = pd.ExcelFile(arquivos[13])

# %%
df1_1b = pd.read_excel(arq1_1, 'TABELA 1.1b')
df1_2b = pd.read_excel(arq1_2, 'Tabela 1.2b')
df2_1a = pd.read_excel(arq2_1, 'TABELA 2.1a')
df2_1b = pd.read_excel(arq2_1, 'TABELA 2.1a')
df2_1c = pd.read_excel(arq2_1, 'TABELA 2.1a')
df2_2a = pd.read_excel(arq2_2, 'TABELA 2.2a')
df2_2b = pd.read_excel(arq2_2, 'TABELA 2.2b')
df2_2c = pd.read_excel(arq2_2, 'TABELA 2.2c')
df2_2d = pd.read_excel(arq2_2, 'TABELA 2.2d')
df2_3a = pd.read_excel(arq2_3, 'TABELA 2.3a')
df2_3b = pd.read_excel(arq2_3, 'TABELA 2.3b')
df3a = pd.read_excel(arq3, 'TABELA 3a')
df3b = pd.read_excel(arq3, 'TABELA 3b')
df4 = pd.read_excel(arq4)
df5a = pd.read_excel(arq5, 'TABELA 5a')
df5b = pd.read_excel(arq5, 'TABELA 5b')
df6a = pd.read_excel(arq6, 'TABELA 6a')
df6b = pd.read_excel(arq6, 'TABELA 6b')
df6c = pd.read_excel(arq6, 'TABELA 6c')
df6d = pd.read_excel(arq6, 'TABELA 6d')
df7a = pd.read_excel(arq7, 'TABELA 7a')
df7b = pd.read_excel(arq7, 'TABELA 7b')
df7c = pd.read_excel(arq7, 'TABELA 7c')
df7d = pd.read_excel(arq7, 'TABELA 7d')
df8a = pd.read_excel(arq8, 'TABELA 8a')
df8b = pd.read_excel(arq8, 'TABELA 8b')
df8c = pd.read_excel(arq8, 'TABELA 8c ')
df9 = pd.read_excel(arq9)
df10a = pd.read_excel(arq10, 'TABELA 10a')
df10b = pd.read_excel(arq10, 'TABELA 10b')
df10c = pd.read_excel(arq10, 'TABELA 10c')
df11 = pd.read_excel(arq11)

# %%
df = [df1_1b,df1_2b,df2_1a,df2_1b,df2_1c,df2_2a,df2_2b,df2_2c,df2_2d,df2_3a,df2_3b,df3a,df3b,df4,df5a,df5b,df6a,df6b,df6c,df6d,
      df7a,df7b,df7c,df7d,df8a,df8b,df8c,df9,df10a,df10b,df10c,df11]

# %%
titulos = []
for i in df:
    nome = i.columns[0] + i[i.columns[0]][0]
    titulos.append(nome)

# %% [markdown]
# ### df1_1b (limpeza)

# %%
df1_1b
# Out:
#    Tabela 1.1 - Variáveis selecionadas das empresas de construção, segundo as divisões, os grupos e as classes de atividades - Brasil - 2011-2012  \
# 0                             Códigos\nda \nCNAE\n2.0
# 1                                                2012
# 2                                                 NaN
# 3                                                 NaN
# 4                                                  41
# 5                                                  42
# 6                                                  43
# 7                                                 NaN
# 8                                                  41
# 9                                                41.1
# 10                                               41.2
# 11                                                 42
# 12                                               42.1
# 13                                               42.2
# 14                                               42.9
# ...

# %%
linhas = [1, 54, 55]
for i in linhas:
    df1_1b = df1_1b.drop(i) #Exclui as linhas que não possui dados
novas_colunas = df1_1b.loc[0]
df1_1b.columns = novas_colunas
df1_1b = df1_1b.drop(0)
#df1_1b.to_csv('tab1_1b_limpa.csv')

# %% [markdown]
# ### df1_2b (limpeza)

# %%
df1_2b
# Out:
#    Tabela 1.2 - Variáveis selecionadas das empresas de construção, segundo as Grandes Regiões  \
# 0   e as Unidades da Federação da sede da empresa ...
# 1   Grandes Regiões \ne\nUnidades da Federação\nda...
# 2                                                 NaN
# 3                                  Total das empresas
# 4                                              Brasil
# 5                                               Norte
# 6                                            Nordeste
# 7                                             Sudeste
# 8                                                 Sul
# 9                                        Centro-Oeste
# 10                 Empresas de 1 a 4 pessoas ocupadas
# 11                                             Brasil
# 12                                              Norte
# 13                                           Nordeste
# 14                                            Sudeste
# 15                                                Sul
# ...

# %%
linhas = [0, 2, 51, 52]
for i in linhas:
    df1_2b = df1_2b.drop(i)
novas_colunas = df1_2b.loc[1]
df1_2b.columns = novas_colunas
df1_2b = df1_2b.drop(1)
#df1_2b.to_csv('tab1_2b_limpa.csv')

# %% [markdown]
# ### df2_1a (limpeza)

# %%
df2_1a
# Out:
#    Tabela 2.1 - Dados gerais das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_1a = df2_1a.drop(i)
novas_colunas = df2_1a.loc[1]
df2_1a.columns = novas_colunas
df2_1a = df2_1a.drop(1)
#df2_1a.to_csv('tab2_1a_limpa.csv')

# %% [markdown]
# ### df2_1b (limpeza)

# %%
df2_1b
# Out:
#    Tabela 2.1 - Dados gerais das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_1b = df2_1b.drop(i)
novas_colunas = df2_1b.loc[1]
df2_1b.columns = novas_colunas
df2_1b = df2_1b.drop(1)
#df2_1b.to_csv('tab2_1b_limpa.csv')

# %% [markdown]
# ### df2_1c (limpeza)

# %%
df2_1c
# Out:
#    Tabela 2.1 - Dados gerais das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_1c = df2_1c.drop(i)
novas_colunas = df2_1c.loc[1]
df2_1c.columns = novas_colunas
df2_1c = df2_1c.drop(1)
#df2_1c.to_csv('tab2_1c_limpa.csv')

# %% [markdown]
# ### df2_2a (limpeza)

# %%
df2_2a
# Out:
#    Tabela 2.2 - Dados gerais das empresas de construção com 5 ou mais pessoas ocupadas,  \
# 0   segundo as divisões, os grupos de atividades e...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 41
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
linhas = [0,2,3,4]
for i in linhas:
    df2_2a = df2_2a.drop(i)
novas_colunas = df2_2a.loc[1]
df2_2a.columns = novas_colunas
df2_2a = df2_2a.drop(1)
#df2_2a.to_csv('tab2_2a_limpa.csv')

# %% [markdown]
# ### df2_2b (limpeza)

# %%
df2_2b
# Out:
#    Tabela 2.2 - Dados gerais das empresas de construção com 5 ou mais pessoas ocupadas,  \
# 0   segundo as divisões, os grupos de atividades e...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                42.9
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 43
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_2b = df2_2b.drop(i)
novas_colunas = df2_2b.loc[1]
df2_2b.columns = novas_colunas
df2_2b = df2_2b.drop(1)
#df2_2b.to_csv('tab2_2b_limpa.csv')

# %% [markdown]
# ### df2_2c (limpeza)

# %%
df2_2c
# Out:
#    Tabela 2.2 - Dados gerais das empresas de construção com 5 ou mais pessoas ocupadas,  \
# 0   segundo as divisões, os grupos de atividades e...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 41
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_2c = df2_2c.drop(i)
novas_colunas = df2_2c.loc[1]
df2_2c.columns = novas_colunas
df2_2c = df2_2c.drop(1)
#df2_2c.to_csv('tab2_2c_limpa.csv')

# %% [markdown]
# ### df2_2d (limpeza)

# %%
df2_2d
# Out:
#    Tabela 2.2 - Dados gerais das empresas de construção com 5 ou mais pessoas ocupadas, segundo  \
# 0   as divisões, os grupos de atividades e as faix...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                42.9
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 43
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
linhas = [0,2,3,4]
for i in linhas:
    df2_2d = df2_2d.drop(i)
novas_colunas = df2_2d.loc[1]
df2_2d.columns = novas_colunas
df2_2d = df2_2d.drop(1)
#df2_2d.to_csv('tab2_2d_limpa.csv')

# %% [markdown]
# ### df2_3a (limpeza)

# %%
df2_3a
# Out:
#    Tabela 2.3 - Dados gerais das empresas de construção, segundo as Grandes Regiões e   \
# 0   as Unidades da Federação da sede da empresa - ...
# 1   Grandes Regiões \ne\n Unidades da Federação \n...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                  Total das empresas
# 6                                             Brasil
# 7                                               Norte
# 8                                            Nordeste
# 9                                             Sudeste
# 10                                                Sul
# 11                                       Centro-Oeste
# 12                 Empresas de 1 a 4 pessoas ocupadas
# 13                                             Brasil
# 14                                              Norte
# 15                                           Nordeste
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_3a = df2_3a.drop(i)
novas_colunas = df2_3a.loc[1]
df2_3a.columns = novas_colunas
df2_3a = df2_3a.drop(1)
#df2_3a.to_csv('tab2_3a_limpa.csv')

# %% [markdown]
# ### df2_3b (limpeza)

# %%
df2_3b
# Out:
#    Tabela 2.3 - Dados gerais das empresas de construção, segundo as Grandes Regiões e   \
# 0   as Unidades da Federação da sede da empresa - ...
# 1   Grandes Regiões \ne\n Unidades da Federação\nd...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                  Total das empresas
# 6                                             Brasil
# 7                                               Norte
# 8                                            Nordeste
# 9                                             Sudeste
# 10                                                Sul
# 11                                       Centro-Oeste
# 12                 Empresas de 1 a 4 pessoas ocupadas
# 13                                             Brasil
# 14                                              Norte
# 15                                           Nordeste
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df2_3b = df2_3b.drop(i)
novas_colunas = df2_3b.loc[1]
df2_3b.columns = novas_colunas
df2_3b = df2_3b.drop(1)
#df2_3b.to_csv('tab2_3b_limpa.csv')

# %% [markdown]
# ### df3a (limpeza)

# %%
df3a
# Out:
#    Tabela 3 - Emprego e salário das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                            Códigos \nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0, 2, 3]
for i in linhas:
    df3a = df3a.drop(i)
novas_colunas = df3a.loc[1]
df3a.columns = novas_colunas
df3a = df3a.drop(1)
#df3a.to_csv('tab3a_limpa.csv')

# %% [markdown]
# ### df3b (limpeza)

# %%
df3b
# Out:
#    Tabela 3 - Emprego e salário das empresas de construção,  \
# 0    segundo as divisões, os grupos e as classes d...
# 1                            Códigos \nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0, 2, 3]
for i in linhas:
    df3b = df3b.drop(i)
novas_colunas = df3b.loc[1]
df3b.columns = novas_colunas
df3b = df3b.drop(1)
#df3b.to_csv('tab3b_limpa.csv')

# %% [markdown]
# ### df4 (limpeza)

# %%
df4
# Out:
#    Tabela 4 - Gastos de pessoal das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                  41
# 6                                                  42
# 7                                                  43
# 8                                                 NaN
# 9                                                  41
# 10                                               41.1
# 11                                               41.2
# 12                                                 42
# 13                                               42.1
# 14                                               42.2
# 15                                               42.9
# ...

# %%
linhas = [0, 2]
for i in linhas:
    df4 = df4.drop(i)
novas_colunas = df4.loc[1]
df4.columns = novas_colunas
df4 = df4.drop(1)
#df4.to_csv('tab4_limpa.csv')

# %% [markdown]
# ### df5a (limpeza)

# %%
df5a
# Out:
#    Tabela 5 - Estrutura das receitas das empresas de construção,   \
# 0    segundo as divisões, os grupos e as classes d...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                  41
# 6                                                  42
# 7                                                  43
# 8                                                 NaN
# 9                                                  41
# 10                                               41.1
# 11                                               41.2
# 12                                                 42
# 13                                               42.1
# 14                                               42.2
# 15                                               42.9
# ...

# %%
linhas = [0, 2]
for i in linhas:
    df5a = df5a.drop(i)
novas_colunas = df5a.loc[1]
df5a.columns = novas_colunas
df5a = df5a.drop(1)
#df5a.to_csv('tab5a_limpa.csv')

# %% [markdown]
# ### df5b (limpeza)

# %%
df5b
# Out:
#    Tabela 5 - Estrutura das receitas das empresas de construção,   \
# 0     segundo as divisões, os grupos e as classes ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                  41
# 5                                                  42
# 6                                                  43
# 7                                                 NaN
# 8                                                  41
# 9                                                41.1
# 10                                               41.2
# 11                                                 42
# 12                                               42.1
# 13                                               42.2
# 14                                               42.9
# 15                                                 43
# ...

# %%
df5b = df5b.drop(0)
novas_colunas = df5b.loc[1]
df5b.columns = novas_colunas
df5b = df5b.drop(1)
#df5b.to_csv('tab5b_limpa.csv')

# %% [markdown]
# ### df6a (limpeza)

# %%
df6a
# Out:
#    Tabela 6 - Estrutura dos custos e despesas das empresas de construção, segundo as divisões,   \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0, 2, 3, 4]
for i in linhas:
    df6a = df6a.drop(i)
novas_colunas = df6a.loc[1]
df6a.columns = novas_colunas
df6a = df6a.drop(1)
#df6a.to_csv('tab6a_limpa.csv')

# %% [markdown]
# ### df6b (limpeza)

# %%
df6b
# Out:
#    Tabela 6 - Estrutura dos custos e despesas das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df6b = df6b.drop(i)
novas_colunas = df6b.loc[1]
df6b.columns = novas_colunas
df6b = df6b.drop(1)
#df6b.to_csv('tab6b_limpa.csv')

# %% [markdown]
# ### df6c (limpeza)

# %%
df6c
# Out:
#    Tabela 6 - Estrutura dos custos e despesas das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df6c = df6c.drop(i)
novas_colunas = df6c.loc[1]
df6c.columns = novas_colunas
df6c = df6c.drop(1)
#df6c.to_csv('tab6c_limpa.csv')

# %% [markdown]
# ### df6d (limpeza)

# %%
df6d
# Out:
#    Tabela 6 - Estrutura dos custos e despesas das empresas de construção, segundo as divisões,  \
# 0   os grupos e as classes de atividades - Brasil ...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0,2,3,4]
for i in linhas:
    df6d = df6d.drop(i)
novas_colunas = df6d.loc[1]
df6d.columns = novas_colunas
df6d = df6d.drop(1)
#df6d.to_csv('tab6d_limpa.csv')

# %% [markdown]
# ### df7a (limpeza)

# %%
df7a
# Out:
#    Tabela 7 - Estrutura do valor bruto da produção das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df7a = df7a.drop(i)
novas_colunas = df7a.loc[1]
df7a.columns = novas_colunas
df7a = df7a.drop(1)
#df7a.to_csv('tab7a_limpa.csv')

# %% [markdown]
# ### df7b (limpeza)

# %%
df7b
# Out:
#    Tabela 7 - Estrutura do valor bruto da produção das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df7b = df7b.drop(i)
novas_colunas = df7b.loc[1]
df7b.columns = novas_colunas
df7b = df7b.drop(1)
#df7b.to_csv('tab7b_limpa.csv')

# %% [markdown]
# ### df7c (limpeza)

# %%
df7c
# Out:
#    Tabela 7 - Estrutura do valor bruto da produção das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df7c = df7c.drop(i)
novas_colunas = df7c.loc[1]
df7c.columns = novas_colunas
df7c = df7c.drop(1)
#df7c.to_csv('tab7c_limpa.csv')

# %% [markdown]
# ### df7d (limpeza)

# %%
df7d
# Out:
#    Tabela 7 - Estrutura do valor bruto da produção das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df7d = df7d.drop(i)
novas_colunas = df7d.loc[1]
df7d.columns = novas_colunas
df7d = df7d.drop(1)
#df7d.to_csv('tab7d_limpa.csv')

# %% [markdown]
# ### df8a (limpeza)

# %%
df8a
# Out:
#    Tabela 8 - Estrutura dos investimentos das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                  41
# 8                                                  42
# 9                                                  43
# 10                                                NaN
# 11                                                 41
# 12                                               41.1
# 13                                               41.2
# 14                                                 42
# 15                                               42.1
# ...

# %%
linhas = [0,2,3,4]
for i in linhas:
    df8a = df8a.drop(i)
novas_colunas = df8a.loc[1]
df8a.columns = novas_colunas
df8a = df8a.drop(1)
df8a.to_csv('tab8a_limpa.csv')

# %% [markdown]
# ### df8b (limpeza)

# %%
df8b
# Out:
#    Tabela 8 - Estrutura dos investimentos das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df8b = df8b.drop(i)
novas_colunas = df8b.loc[1]
df8b.columns = novas_colunas
df8b = df8b.drop(1)
#df8b.to_csv('tab8b_limpa.csv')

# %% [markdown]
# ### df8c (limpeza)

# %%
df8c
# Out:
#    Tabela 8 - Estrutura dos investimentos das empresas de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                             Códigos\nda \nCNAE\n2.0
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                  41
# 7                                                  42
# 8                                                  43
# 9                                                 NaN
# 10                                                 41
# 11                                               41.1
# 12                                               41.2
# 13                                                 42
# 14                                               42.1
# 15                                               42.2
# ...

# %%
linhas = [0,2,3]
for i in linhas:
    df8c = df8c.drop(i)
novas_colunas = df8c.loc[1]
df8c.columns = novas_colunas
df8c = df8c.drop(1)
#df8c.to_csv('tab8c_limpa.csv')

# %% [markdown]
# ### df9 (limpeza)

# %%
df9
# Out:
#    Tabela 9 - Consumo total e dos principais tipos de materiais de construção,   \
# 0   segundo as divisões, os grupos e as classes de...
# 1                                                 NaN
# 2                                                 NaN
# 3                             Códigos\nda \nCNAE\n2.0
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                  41
# 10                                                 42
# 11                                                 43
# 12                                                NaN
# 13                                                 41
# 14                                               41.1
# 15                                               41.2
# ...

# %%
linhas = [0,1,2,4,5,6]
for i in linhas:
    df9 = df9.drop(i)
novas_colunas = df9.loc[3]
df9.columns = novas_colunas
df9 = df9.drop(3)
#df9.to_csv('tab9_limpa.csv')

# %% [markdown]
# ### df10a (limpeza)

# %%
df10a
# Out:
#    Tabela 10 - Valor das incorporações, obras e/ou serviços da construção das empresas de construção com 30 ou mais  \
# 0   pessoas ocupadas, segundo as classes de ativid...
# 1                        Código\nPRODLIST\nConstrução
# 2                                                 NaN
# 3                                                 NaN
# 4                                                4110
# 5                                           4110.2010
# 6                                                4120
# 7                                           4120.2010
# 8                                          4120.2020
# 9                                          4120.2030
# 10                                          4120.2040
# 11                                         4120.2050
# 12                                         4120.9010
# 13                                         4120.9020
# 14                                         4120.9030
# ...

# %%
linhas = [0,2]
for i in linhas:
    df10a = df10a.drop(i)
novas_colunas = df10a.loc[1]
df10a.columns = novas_colunas
df10a = df10a.drop(1)
#df10a.to_csv('tab10a_limpa.csv')

# %% [markdown]
# ### df10b (limpeza)

# %%
df10b
# Out:
#    Tabela 10 - Valor das incorporações, obras e/ou serviços da construção das empresas de construção com 30 ou mais  \
# 0   pessoas ocupadas, segundo as classes de ativid...
# 1                        Código\nPRODLIST\nConstrução
# 2                                                 NaN
# 3                                                4222
# 4                                          4222.2010
# 5                                          4222.2020
# 6                                          4222.2030
# 7                                          4222.9010
# 8                                          4222.9020
# 9                                                4223
# 10                                         4223.2010
# 11                                         4223.9010
# 12                                               4291
# 13                                         4291.2010
# 14                                         4291.2020
# ...

# %%
linhas = [0,2]
for i in linhas:
    df10b = df10b.drop(i)
novas_colunas = df10b.loc[1]
df10b.columns = novas_colunas
df10b = df10b.drop(1)
#df10b.to_csv('tab10b_limpa.csv')

# %% [markdown]
# ### df10c (limpeza)

# %%
df10c
# Out:
#    Tabela 10 - Valor das incorporações, obras e/ou serviços da construção das empresas de construção com 30 ou mais  \
# 0   pessoas ocupadas, segundo as classes de ativid...
# 1                        Código\nPRODLIST\nConstrução
# 2                                                 NaN
# 3                                                4321
# 4                                          4321.2010
# 5                                          4321.2020
# 6                                          4321.9010
# 7                                          4321.9020
# 8                                                4322
# 9                                          4322.2010
# 10                                         4322.2020
# 11                                         4322.9010
# 12                                               4329
# 13                                         4329.2010
# 14                                         4329.2020
# ...

# %%
linhas = [0,2]
for i in linhas:
    df10c = df10c.drop(i)
novas_colunas = df10c.loc[1]
df10c.columns = novas_colunas
df10c = df10c.drop(1)
#df10c.to_csv('tab10c_limpa.csv')

# %% [markdown]
# ### df11 (limpeza)

# %%
df11
# Out:
#    Tabela 11 - Pessoal ocupado, salários, retiradas e outras remunerações, custos e valor das incorporações, obras   \
# 0   e/ou serviços da construção, segundo as Grande...
# 1   empresas com 5 ou mais pessoas ocupadas - Bras...
# 2   Grandes Regiões\ne\nUnidades da Federação \nde...
# 3                                                 NaN
# 4                                              Brasil
# 5                                               Norte
# 6                                            Rondônia
# 7                                                Acre
# 8                                            Amazonas
# 9                                             Roraima
# 10                                               Pará
# 11                                              Amapá
# 12                                          Tocantins
# 13                                           Nordeste
# 14                                           Maranhão
# ...

# %%
linhas = [0,1,3]
for i in linhas:
    df11 = df11.drop(i)
novas_colunas = df11.loc[2]
df11.columns = novas_colunas
df11 = df11.drop(2)
#df11.to_csv('tab11_limpa.csv')
